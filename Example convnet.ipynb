# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten,Conv2D, MaxPooling2D, BatchNormalization
import pickle
from sklearn import preprocessing
from keras import backend as K
import os
import cv2
from keras.callbacks import TensorBoard
from tempfile import TemporaryFile
import time
from img_prep import img_prep
from convnet6layers import convnet_64
# Out:
# /home/howard/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
dirs = "presi-caricature"
img_sz = 150
IMG = img_prep(datadir=dirs, img_sz = img_sz, color = 'c')
#if you want gray scale put g
#if you want color put c

# %%
IMG.show_resize_img(imgu_SIZE=150)
# Out:
# coloro

# %%
X, Y, numtolet = IMG.create_train_data()

# %%
conv = convnet_64(X,Y,IMG.categories_len,epoc=5, bat_sz=16)

# %%
conv.convnet()

# %%
conv.save_model()

# %%
swag = conv.model.metrics['accuracy'][:1]
print(swag)
